# %%
import pandas as pd
import numpy as np

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva", "Frank", "Grace"],
    "Age": [25, 30, 35, 40, 22, 28, 45],
    "City": ["New York", "Los Angeles", "Chicago", "Houston", "Phoenix", "Philadelphia", "San Antonio"],
    "Salary": [70000, 80000, 120000, 90000, 60000, 75000, 110000]
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age          City  Salary
# 0    Alice   25      New York   70000
# 1      Bob   30   Los Angeles   80000
# 2  Charlie   35       Chicago  120000
# 3    David   40       Houston   90000
# 4      Eva   22       Phoenix   60000
# 5    Frank   28  Philadelphia   75000
# 6    Grace   45   San Antonio  110000

# %%
# 1. Create and Inspect: Create a DataFrame from the data dictionary. Print the specific shape of the DataFrame (rows, columns) and show the data types of all columns.

df = pd.DataFrame(data)
print(df)
print(df.shape)
print(df.dtypes)
# Out:
#       Name  Age          City  Salary
# 0    Alice   25      New York   70000
# 1      Bob   30   Los Angeles   80000
# 2  Charlie   35       Chicago  120000
# 3    David   40       Houston   90000
# 4      Eva   22       Phoenix   60000
# 5    Frank   28  Philadelphia   75000
# 6    Grace   45   San Antonio  110000
# (7, 4)
# Name      object
# Age        int64
# City      object
# Salary     int64
# dtype: object

# %%
# 2. Custom Index creation: Create a new DataFrame df_custom from data but set the index to be specific IDs: ['ID1', 'ID2', 'ID3', 'ID4', 'ID5', 'ID6', 'ID7'].

custom_index = ['ID1', 'ID2', 'ID3', 'ID4', 'ID5', 'ID6', 'ID7']
df_custom = pd.DataFrame(data,index=custom_index)
print(df_custom)
# Out:
#         Name  Age          City  Salary
# ID1    Alice   25      New York   70000
# ID2      Bob   30   Los Angeles   80000
# ID3  Charlie   35       Chicago  120000
# ID4    David   40       Houston   90000
# ID5      Eva   22       Phoenix   60000
# ID6    Frank   28  Philadelphia   75000
# ID7    Grace   45   San Antonio  110000

# %%
# 3. Column Selection: Create a new DataFrame df_subset containing only the "Name" and "Salary" columns from df.

df_subset = df[['Name','Salary']]
print(df_subset)
# Out:
#       Name  Salary
# 0    Alice   70000
# 1      Bob   80000
# 2  Charlie  120000
# 3    David   90000
# 4      Eva   60000
# 5    Frank   75000
# 6    Grace  110000

# %%
# 4. Row Slicing (Integer): Use iloc to select rows 2 through 5 (inclusive of index 2, exclusive of 5 depending on slice logic, or just indices 2,3,4) and all columns.

data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva", "Frank", "Grace"],
    "Age": [25, 30, 35, 40, 22, 28, 45],
    "City": ["New York", "Los Angeles", "Chicago", "Houston", "Phoenix", "Philadelphia", "San Antonio"],
    "Salary": [70000, 80000, 120000, 90000, 60000, 75000, 110000]
}
df = pd.DataFrame(data)
df = df.iloc[2:5]
print(df)
# Out:
#       Name  Age     City  Salary
# 2  Charlie   35  Chicago  120000
# 3    David   40  Houston   90000
# 4      Eva   22  Phoenix   60000

# %%
# 5. Row and Column Slicing (Label): Use loc to select the "Name" and "Age" for the rows with index labels 1, 3, and 5.

data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva", "Frank", "Grace"],
    "Age": [25, 30, 35, 40, 22, 28, 45],
    "City": ["New York", "Los Angeles", "Chicago", "Houston", "Phoenix", "Philadelphia", "San Antonio"],
    "Salary": [70000, 80000, 120000, 90000, 60000, 75000, 110000]
}
df = pd.DataFrame(data)

df = df.loc[[1,3,5],['Name','Age']]
print(df)
# Out:
#     Name  Age
# 1    Bob   30
# 3  David   40
# 5  Frank   28

# %%
# 6. Cell Access: Use iloc to print the "City" of the 4th row (index 3).

data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva", "Frank", "Grace"],
    "Age": [25, 30, 35, 40, 22, 28, 45],
    "City": ["New York", "Los Angeles", "Chicago", "Houston", "Phoenix", "Philadelphia", "San Antonio"],
    "Salary": [70000, 80000, 120000, 90000, 60000, 75000, 110000]
}
df = pd.DataFrame(data)

print(df.iloc[3,2])
# Out:
# Houston

# %%
# 7. Head and Tail: Print the first 3 rows and the last 2 rows of the DataFrame in a single script execution.

print(df.head(3))
print(df.tail(2))
# Out:
#       Name  Age         City  Salary
# 0    Alice   25     New York   70000
# 1      Bob   30  Los Angeles   80000
# 2  Charlie   35      Chicago  120000
#     Name  Age          City  Salary
# 5  Frank   28  Philadelphia   75000
# 6  Grace   45   San Antonio  110000

# %%
# 8. Describe Objects: Use df.describe() but try to include all columns (including objects like strings), not just numbers. (Hint: look up include='all' or check dtypes).

print(df.describe(include='all'))
# Out:
#          Name        Age      City         Salary
# count       7   7.000000         7       7.000000
# unique      7        NaN         7            NaN
# top     Alice        NaN  New York            NaN
# freq        1        NaN         1            NaN
# mean      NaN  32.142857       NaN   86428.571429
# std       NaN   8.275034       NaN   21739.803302
# min       NaN  22.000000       NaN   60000.000000
# 25%       NaN  26.500000       NaN   72500.000000
# 50%       NaN  30.000000       NaN   80000.000000
# 75%       NaN  37.500000       NaN  100000.000000
# max       NaN  45.000000       NaN  120000.000000

# %%
# 9. Rename Single: Rename the "Salary" column to "Annual Income" in place (or reassign to df).

df = df.rename(columns={"Salary":"Annual Income"})
print(df)
# Out:
#       Name  Age          City  Annual Income
# 0    Alice   25      New York          70000
# 1      Bob   30   Los Angeles          80000
# 2  Charlie   35       Chicago         120000
# 3    David   40       Houston          90000
# 4      Eva   22       Phoenix          60000
# 5    Frank   28  Philadelphia          75000
# 6    Grace   45   San Antonio         110000

# %%
# 10. Rename Multiple: Rename "Name" to "Full Name" and "City" to "Location" simultaneously.

data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva", "Frank", "Grace"],
    "Age": [25, 30, 35, 40, 22, 28, 45],
    "City": ["New York", "Los Angeles", "Chicago", "Houston", "Phoenix", "Philadelphia", "San Antonio"],
    "Salary": [70000, 80000, 120000, 90000, 60000, 75000, 110000]
}
df = pd.DataFrame(data)
df = df.rename(columns={"Name":"Full Name","City":"Location"})
print(df)
# Out:
#   Full Name  Age      Location  Salary
# 0     Alice   25      New York   70000
# 1       Bob   30   Los Angeles   80000
# 2   Charlie   35       Chicago  120000
# 3     David   40       Houston   90000
# 4       Eva   22       Phoenix   60000
# 5     Frank   28  Philadelphia   75000
# 6     Grace   45   San Antonio  110000

# %%
# 11. Drop Column: Remove the "City" column from the DataFrame.

df = df.drop("Location",axis=1)
print(df)
# Out:
#   Full Name  Age  Salary
# 0     Alice   25   70000
# 1       Bob   30   80000
# 2   Charlie   35  120000
# 3     David   40   90000
# 4       Eva   22   60000
# 5     Frank   28   75000
# 6     Grace   45  110000

# %%
# 12. Drop Row: Remove the row at index 3.

data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva", "Frank", "Grace"],
    "Age": [25, 30, 35, 40, 22, 28, 45],
    "City": ["New York", "Los Angeles", "Chicago", "Houston", "Phoenix", "Philadelphia", "San Antonio"],
    "Salary": [70000, 80000, 120000, 90000, 60000, 75000, 110000]
}
df = pd.DataFrame(data)

df = df.drop(3,axis=0)
print(df)
# Out:
#       Name  Age          City  Salary
# 0    Alice   25      New York   70000
# 1      Bob   30   Los Angeles   80000
# 2  Charlie   35       Chicago  120000
# 4      Eva   22       Phoenix   60000
# 5    Frank   28  Philadelphia   75000
# 6    Grace   45   San Antonio  110000

# %%
# 13. Add Constant Column: Add a new column "Country" and populate it with "USA" for all rows.

data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva", "Frank", "Grace"],
    "Age": [25, 30, 35, 40, 22, 28, 45],
    "City": ["New York", "Los Angeles", "Chicago", "Houston", "Phoenix", "Philadelphia", "San Antonio"],
    "Salary": [70000, 80000, 120000, 90000, 60000, 75000, 110000]
}
df = pd.DataFrame(data)

df.insert(4, "Country", "USA")
print(df)
# Out:
#       Name  Age          City  Salary Country
# 0    Alice   25      New York   70000     USA
# 1      Bob   30   Los Angeles   80000     USA
# 2  Charlie   35       Chicago  120000     USA
# 3    David   40       Houston   90000     USA
# 4      Eva   22       Phoenix   60000     USA
# 5    Frank   28  Philadelphia   75000     USA
# 6    Grace   45   San Antonio  110000     USA

# %%
# 14. Add Calculated Column (Born Year): Assuming the current year is 2025, create a new column "Birth Year" by subtracting "Age" from 2025.

df = pd.DataFrame(data)

df.insert(4,"Birth Year",2025 - df["Age"])
print(df)
# Out:
#       Name  Age          City  Salary  Birth Year
# 0    Alice   25      New York   70000        2000
# 1      Bob   30   Los Angeles   80000        1995
# 2  Charlie   35       Chicago  120000        1990
# 3    David   40       Houston   90000        1985
# 4      Eva   22       Phoenix   60000        2003
# 5    Frank   28  Philadelphia   75000        1997
# 6    Grace   45   San Antonio  110000        1980

# %%
# 15. Add List Column: Add a new column "Department" using this list: ['HR', 'Eng', 'Eng', 'Sales', 'HR', 'Sales', 'Admin'].

# df.insert(4,"Department", ['HR', 'Eng', 'Eng', 'Sales', 'HR', 'Sales', 'Admin'])
df["Department"] = ['HR', 'Eng', 'Eng', 'Sales', 'HR', 'Sales', 'Admin']
print(df)
# Out:
#       Name  Age          City  Salary  Birth Year Department
# 0    Alice   25      New York   70000        2000         HR
# 1      Bob   30   Los Angeles   80000        1995        Eng
# 2  Charlie   35       Chicago  120000        1990        Eng
# 3    David   40       Houston   90000        1985      Sales
# 4      Eva   22       Phoenix   60000        2003         HR
# 5    Frank   28  Philadelphia   75000        1997      Sales
# 6    Grace   45   San Antonio  110000        1980      Admin

# %%
# 16. Numpy conversion: Convert the underlying data of the DataFrame to a NumPy array and print it.

data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva", "Frank", "Grace"],
    "Age": [25, 30, 35, 40, 22, 28, 45],
    "City": ["New York", "Los Angeles", "Chicago", "Houston", "Phoenix", "Philadelphia", "San Antonio"],
    "Salary": [70000, 80000, 120000, 90000, 60000, 75000, 110000]
}
df = pd.DataFrame(data)


df = df.values
print(df)
# Out:
# [['Alice' 25 'New York' 70000]
#  ['Bob' 30 'Los Angeles' 80000]
#  ['Charlie' 35 'Chicago' 120000]
#  ['David' 40 'Houston' 90000]
#  ['Eva' 22 'Phoenix' 60000]
#  ['Frank' 28 'Philadelphia' 75000]
#  ['Grace' 45 'San Antonio' 110000]]

# %%
# 17. Empty DataFrame: Create an empty DataFrame. Then add two columns "A" and "B" with 3 values each.

df_empty = pd.DataFrame()
df_empty["A"] = [1,2,3]
df_empty["B"] = [4,5,6]
print(df_empty)
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
# 18. Reorder Columns: Rearrange the columns so that "Age" appears before "Name".

data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva", "Frank", "Grace"],
    "Age": [25, 30, 35, 40, 22, 28, 45],
    "City": ["New York", "Los Angeles", "Chicago", "Houston", "Phoenix", "Philadelphia", "San Antonio"],
    "Salary": [70000, 80000, 120000, 90000, 60000, 75000, 110000]
}
df = pd.DataFrame(data)


df = df[["Age","Name","City","Salary"]]
print(df)

cols = list(df.columns)
cols.insert(0, cols.pop(cols.index("Age")))
df = df[cols]
print("\nAfter reordering columns:\n", df)
# Out:
#    Age     Name          City  Salary
# 0   25    Alice      New York   70000
# 1   30      Bob   Los Angeles   80000
# 2   35  Charlie       Chicago  120000
# 3   40    David       Houston   90000
# 4   22      Eva       Phoenix   60000
# 5   28    Frank  Philadelphia   75000
# 6   45    Grace   San Antonio  110000
#
# After reordering columns:
#     Age     Name          City  Salary
# 0   25    Alice      New York   70000
# 1   30      Bob   Los Angeles   80000
# 2   35  Charlie       Chicago  120000
# 3   40    David       Houston   90000
# 4   22      Eva       Phoenix   60000
# 5   28    Frank  Philadelphia   75000
# 6   45    Grace   San Antonio  110000

# %%
# 19. Conditional Update (Manual): Update the "Age" of "Alice" (index 0) to 26 using at or loc.

data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva", "Frank", "Grace"],
    "Age": [25, 30, 35, 40, 22, 28, 45],
    "City": ["New York", "Los Angeles", "Chicago", "Houston", "Phoenix", "Philadelphia", "San Antonio"],
    "Salary": [70000, 80000, 120000, 90000, 60000, 75000, 110000]
}
df = pd.DataFrame(data)

df.loc[0, "Age"] = 26
print(df)
# Out:
#       Name  Age          City  Salary
# 0    Alice   26      New York   70000
# 1      Bob   30   Los Angeles   80000
# 2  Charlie   35       Chicago  120000
# 3    David   40       Houston   90000
# 4      Eva   22       Phoenix   60000
# 5    Frank   28  Philadelphia   75000
# 6    Grace   45   San Antonio  110000

# %%
# 20. Random Sample: specificy a random seed (optional) and select a random sample of 3 rows from the DataFrame.

df = df.sample(3)
print(df)
# Out:
#       Name  Age         City  Salary
# 6    Grace   45  San Antonio  110000
# 4      Eva   22      Phoenix   60000
# 2  Charlie   35      Chicago  120000
